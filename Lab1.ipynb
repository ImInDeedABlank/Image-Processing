# %%
# This lab is about how digital images are represented and manipulated in a computer

# %%
# Task 2:
# a)
import cv2
img = cv2.imread(r"Pics\Grayscale_Motherboard.jpg") #Load the image
import matplotlib.pyplot as plt
plt.imshow(img)
plt.show()

# b)
from PIL import Image
img2 = Image.open(r"Pics\Grayscale_Motherboard.jpg") #load the image using PIL
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.imshow(img2, cmap = cm.Greys_r)
plt.show()

# %%
# Task 3
# a)
cv2.imwrite('new_image.jpg', img)

# b)
img2.save('new_image2.jpg')
# Out:
# True

# %%
# Task 4
print(img.shape) #Note: img1 loaded using open cv is a numpy array
print(img)

import numpy as np
# Convert the image to a NumPy array
img_array = np.array(img2)
# Print the array
print(img_array.shape)
print(img_array)
# Out:
# (3632, 5456, 3)
# [[[6 6 6]
#   [6 6 6]
#   [5 5 5]
#   ...
#   [4 4 4]
#   [4 4 4]
#   [4 4 4]]
#
#  [[6 6 6]
#   [6 6 6]
#   [5 5 5]
#   ...
#   [4 4 4]
#   [4 4 4]
#   [4 4 4]]
#
#  [[6 6 6]
#   [6 6 6]
#   [5 5 5]
#   ...
#   [4 4 4]
#   [4 4 4]
#   [4 4 4]]
#
#  ...
#
#  [[7 7 7]
#   [9 9 9]
#   [9 9 9]
#   ...
#   [4 4 4]
#   [4 4 4]
#   [4 4 4]]
#
#  [[7 7 7]
#   [8 8 8]
#   [9 9 9]
#   ...
#   [4 4 4]
#   [4 4 4]
#   [4 4 4]]
#
#  [[7 7 7]
#   [8 8 8]
#   [9 9 9]
#   ...
#   [4 4 4]
#   [4 4 4]
#   [4 4 4]]]
# (3632, 5456, 3)
# [[[6 6 6]
#   [6 6 6]
#   [5 5 5]
#   ...
#   [4 4 4]
#   [4 4 4]
#   [4 4 4]]
#
#  [[6 6 6]
#   [6 6 6]
#   [5 5 5]
#   ...
#   [4 4 4]
#   [4 4 4]
#   [4 4 4]]
#
#  [[6 6 6]
#   [6 6 6]
#   [5 5 5]
#   ...
#   [4 4 4]
#   [4 4 4]
#   [4 4 4]]
#
#  ...
#
#  [[7 7 7]
#   [9 9 9]
#   [9 9 9]
#   ...
#   [4 4 4]
#   [4 4 4]
#   [4 4 4]]
#
#  [[7 7 7]
#   [8 8 8]
#   [9 9 9]
#   ...
#   [4 4 4]
#   [4 4 4]
#   [4 4 4]]
#
#  [[7 7 7]
#   [8 8 8]
#   [9 9 9]
#   ...
#   [4 4 4]
#   [4 4 4]
#   [4 4 4]]]
